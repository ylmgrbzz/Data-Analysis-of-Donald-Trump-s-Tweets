# %% [markdown]
# <a href="https://colab.research.google.com/github/ylmgrbzz/Data-Analysis-of-Donald-Trump-s-Tweets/blob/main/Data_Analysis_of_Donald_Trump's_Tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
trump=pd.read_csv("trump.csv")

# %%
trump.head(3)
# Out:
#    Unnamed: 0        date          target                  insult  \
# 0           1  2014-10-09  thomas-frieden                    fool
# 1           2  2014-10-09  thomas-frieden                    DOPE
# 2           3  2015-06-16     politicians  all talk and no action
#
#                                                tweet
# 0  Can you believe this fool, Dr. Thomas Frieden ...
# 1  Can you believe this fool, Dr. Thomas Frieden ...
# 2  Big time in U.S. today - MAKE AMERICA GREAT AG...

# %%
trump=trump.drop("Unnamed: 0", axis=1)

# %%
trump.head(3)
# Out:
#          date          target                  insult  \
# 0  2014-10-09  thomas-frieden                    fool
# 1  2014-10-09  thomas-frieden                    DOPE
# 2  2015-06-16     politicians  all talk and no action
#
#                                                tweet
# 0  Can you believe this fool, Dr. Thomas Frieden ...
# 1  Can you believe this fool, Dr. Thomas Frieden ...
# 2  Big time in U.S. today - MAKE AMERICA GREAT AG...

# %%
trump.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10360 entries, 0 to 10359
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    10360 non-null  object
#  1   target  10358 non-null  object
#  2   insult  10360 non-null  object
#  3   tweet   10360 non-null  object
# dtypes: object(4)
# memory usage: 323.9+ KB

# %%
trump['date']=pd.to_datetime(trump["date"])

# %%
trump=trump.set_index("date")

# %%
trump
# Out:
#                     target                                             insult  \
# date
# 2014-10-09  thomas-frieden                                               fool
# 2014-10-09  thomas-frieden                                               DOPE
# 2015-06-16     politicians                             all talk and no action
# 2015-06-24      ben-cardin  It's politicians like Cardin that have destroy...
# 2015-06-24      neil-young                                    total hypocrite
# ...                    ...                                                ...
# 2021-01-06   2020-election  Many States want to decertify the mistake they...
# 2021-01-06   2020-election  based on irregularities and fraud, plus corrup...
# 2021-01-06   2020-election  Our Election Process is worse than that of thi...
# 2021-01-06   2020-election                                            a FRAUD
# 2021-01-06      chuck-todd                        Sleepy Eyes,  Sad to watch!
#
#                                                         tweet
# date
# 2014-10-09  Can you believe this fool, Dr. Thomas Frieden ...
# 2014-10-09  Can you believe this fool, Dr. Thomas Frieden ...
# 2015-06-16  Big time in U.S. today - MAKE AMERICA GREAT AG...
# 2015-06-24  Politician @SenatorCardin didn't like that I s...
# 2015-06-24  For the nonbeliever, here is a photo of @Neily...
# ...                                                       ...
# 2021-01-06  If Vice President @Mike_Pence comes through fo...
# 2021-01-06  States want to correct their votes, which they...
# 2021-01-06  They just happened to find 50,000 ballots late...
# 2021-01-06  The States want to redo their votes. They foun...
# 2021-01-06  Sleepy Eyes Chuck Todd is so happy with the fa...
#
# [10360 rows x 3 columns]

# %%
trump.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10360 entries, 2014-10-09 to 2021-01-06
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  10358 non-null  object
#  1   insult  10360 non-null  object
#  2   tweet   10360 non-null  object
# dtypes: object(3)
# memory usage: 323.8+ KB

# %%
trump["tweet"]=trump["tweet"].str.lower()

# %%
trump.head(3)
# Out:
#                     target                  insult  \
# date
# 2014-10-09  thomas-frieden                    fool
# 2014-10-09  thomas-frieden                    DOPE
# 2015-06-16     politicians  all talk and no action
#
#                                                         tweet
# date
# 2014-10-09  can you believe this fool, dr. thomas frieden ...
# 2014-10-09  can you believe this fool, dr. thomas frieden ...
# 2015-06-16  big time in u.s. today - make america great ag...

# %%
trump[trump['tweet'].str.contains("turkey")]
# Out:
#                            target  \
# date
# 2017-11-24  middle-east-relations
# 2017-11-24  middle-east-relations
# 2018-07-19                 turkey
# 2018-08-16                 turkey
# 2019-10-09           endless-wars
#
#                                                        insult  \
# date
# 2017-11-24                          the mess that I inherited
# 2017-11-24  what a mistake, in lives and dollars (6 trilli...
# 2018-07-19                                   A total disgrace
# 2018-08-16  has taken advantage of the United States for m...
# 2019-10-09                                             stupid
#
#                                                         tweet
# date
# 2017-11-24  will be speaking to president recep tayyip erd...
# 2017-11-24  will be speaking to president recep tayyip erd...
# 2018-07-19  a total disgrace that turkey will not release ...
# 2018-08-16  turkey has taken advantage of the united state...
# 2019-10-09  fighting between various groups that has been ...

# %%
# !pip install country_list
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: country_list in /usr/local/lib/python3.7/dist-packages (1.0.0)

# %%
import country_list as cl

# %%
dir(cl)
# Out:
# ['__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__email__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'available_languages',
#  'countries_for_language',
#  'country_list']

# %%
trump=trump.dropna()

# %%
all=" ".join(trump["tweet"])

# %%
all_list=all.split(" ")

# %%
etiketler=[]
for kelime in all_list:
    if len(kelime)>0:
       if kelime[0]=="@":
          etiketler.append(kelime)

# %%
etiketler
# Out:
# ['@senatorcardin',
#  '@neilyoung',
#  '@foxnews',
#  '@alwaleedbint',
#  '@macys.',
#  '@macys',
#  '@macys',
#  '@macys',
#  '@macys',
#  '@macys',
#  '@ericbolling',
#  '@macys',
#  '@krauthammer',
#  '@krauthammer',
#  '@clare_oc',
#  '@forbes',
#  '@clare_oc',
#  '@forbes',
#  '@clare_oc',
#  '@forbes',
#  '@clare_oc',
#  '@forbes',
#  '@clare_oc',
#  '@forbes:',
#  '@forbes',
#  '@clare_oc',
#  '@forbes',
#  '@clare_oc',
#  '@macys',
#  '@univision.',
#  '@univision.',
#  '@univision.',
#  '@chucktodd',
#  '@chucktodd',
#  '@chucktodd',
#  '@chucktodd',
#  '@chucktodd',
#  '@chucktodd',
#  '@mets',
#  '@nydailynews',
#  '@karlrove',
#  '@foxnews?',
#  '@karlrove',
#  '@karlrove',
#  '@karlrove',
#  '@foxnews',
#  '@karlrove',
#  '@foxnews',
#  '@karlrove',
#  '@foxnews',
#  '@pennjillette',
#  '@pennjillette',
#  '@pennjillette',
#  '@pennjillette',
#  '@macys',
#  '@karlrove',
#  '@foxnews',
#  '@foxnews',
#  '@foxnews',
#  '@lawrence',
#  '@lawrence',
#  '@lawrence',
#  '@pennjillette.',
#  '@pennjillette.',
#  '@ariannahuff',
#  '@huffingtonpost',
#  '@ariannahuff',
#  '@huffingtonpost',
#  '@ariannahuff',
#  '@huffingtonpost',
#  '@ariannahuff',
#  '@huffingtonpost',
#  '@cnn',
#  '@cnnpolitics',
#  '@cnn',
#  '@cnnpolitics',
#  '@cnn',
#  '@cnnpolitics',
#  '@cnn',
#  '@cnnpolitics',
#  '@mittromney?',
#  '@mittromney?',
#  '@wsj',
#  '@wsj.',
#  '@chucktodd',
#  '@nbc',
#  '@macys,',
#  '@macys,',
#  '@andersoncooper',
#  '@andersoncooper',
#  '@danaperino.',
#  '@huffingtonpost',
#  '@ariannahuff',
#  '@huffingtonpost',
#  '@ariannahuff',
#  '@ppfa',
#  '@foxnews',
#  '@seanhannity',
#  '@cnnpolitics',
#  '@cnnpolitics',
#  '@cnnpolitics',
#  '@morning_joe',
#  '@morning_joe',
#  '@foxnews',
#  '@foxnews',
#  '@danhenninger',
#  '@wsj',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@drudge_report',
#  '@time',
#  '@megynkelly',
#  '@foxnews',
#  '@megynkelly,',
#  '@foxnews',
#  '@megynkelly,',
#  '@krauthammer',
#  '@foxnews',
#  '@krauthammer',
#  '@foxnews',
#  '@krauthammer',
#  '@foxnews',
#  '@redstate',
#  '@redstate',
#  '@foxnews.',
#  '@randpaul',
#  '@huffingtonpost',
#  '@nbc',
#  '@huffingtonpost',
#  '@nbc',
#  '@foxnews',
#  '@abcpolitics',
#  '@oreillyfactor',
#  '@foxnews',
#  '@oreillyfactor',
#  '@foxnews',
#  '@oreillyfactor,',
#  '@foxnews',
#  '@thefive',
#  '@foxnews',
#  '@thefive',
#  '@foxnews',
#  '@thefive',
#  '@foxnews',
#  '@thefive',
#  '@foxnews',
#  '@cnn.',
#  '@sentedcruz',
#  '@ingrahamangle',
#  '@foxnews,',
#  '@karlrove',
#  '@seanhannity',
#  '@foxnews.',
#  '@bobbyjindal,',
#  '@bobbyjindal,',
#  '@randpaul',
#  '@randpaul,',
#  '@club4growth',
#  '@megynkelly',
#  '@megynkelly',
#  '@megynkelly',
#  '@richlowry',
#  '@foxnews.',
#  '@richlowry',
#  '@foxnews.',
#  '@richlowry',
#  '@nytimes',
#  '@politico',
#  '@politico',
#  '@politico',
#  '@marcorubio',
#  '@marcorubio',
#  '@marcorubio',
#  '@politico',
#  '@politico',
#  '@marcorubio',
#  '@marcorubio',
#  '@club4growth',
#  '@club4growth',
#  '@politico',
#  '@glennbeck',
#  '@glennbeck',
#  '@glennbeck',
#  '@glennbeck',
#  '@glennbeck',
#  '@ewerickson',
#  '@ewerickson',
#  '@redstate',
#  '@redstate',
#  '@politico,',
#  '@politico,',
#  '@60minutes',
#  '@60minutes',
#  '@gop',
#  '@cnbc',
#  '@gop',
#  '@gop',
#  '@vanityfair',
#  '@vanityfair',
#  '@jebbush,',
#  '@mittromney',
#  '@pennjillette',
#  '@megynkelly',
#  '@cnn',
#  '@jaketapper.',
#  '@billkristol,',
#  '@morning_joe',
#  '@billkristol,',
#  '@morning_joe',
#  '@politico',
#  '@politico',
#  '@cnbc',
#  '@cnbc',
#  '@politico',
#  '@politico',
#  '@politico',
#  '@glennbeck,',
#  '@politico.',
#  '@cnbc.',
#  '@wsj',
#  '@fortunemagazine',
#  '@cnbc.',
#  '@cnbc.',
#  '@nytimes',
#  '@nytimes',
#  '@realdonaldtrump',
#  '@billkristol',
#  '@billkristol',
#  '@jmartnyt',
#  '@jmartnyt',
#  '@foxnews.',
#  '@foxnews.',
#  '@wsj',
#  '@wsj',
#  '@wsj',
#  '@wsj',
#  '@karlrove',
#  '@wsj',
#  '@karlrove',
#  '@karlrove',
#  '@karlrove',
#  '@karlrove',
#  '@forbes',
#  '@wsj',
#  '@shepnewsteam',
#  '@shepnewsteam',
#  '@vanityfair',
#  '@vanityfair',
#  '@rondarousey',
#  '@tmobile',
#  '@tmobile',
#  '@tmobile',
#  '@karlrove',
#  '@ap.',
#  '@georgewill,',
#  '@foxnews.',
#  '@georgewill,',
#  '@foxnews.',
#  '@georgewill,',
#  '@foxnews.',
#  '@georgewill,',
#  '@foxnews.',
#  '@georgewill,',
#  '@foxnews.',
#  '@georgewill,',
#  '@georgewill',
#  '@thejuanwilliams',
#  '@billdeblasio,',
#  '@ap',
#  '@ap',
#  '@ap',
#  '@reuters',
#  '@ap.',
#  '@jeffhorwitz',
#  '@jeffhorwitz',
#  '@jeffhorwitz',
#  '@macys',
#  '@gop',
#  '@karlrove',
#  '@greta',
#  '@karlrove',
#  '@greta',
#  '@karlrove',
#  '@morning_joe.',
#  '@foxnews',
#  '@karlrove',
#  '@morning_joe.',
#  '@foxnews',
#  '@karlrove',
#  '@morning_joe.',
#  '@foxnews',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@cnn',
#  '@realdonaldtrump',
#  '@cnn',
#  '@cnn',
#  '@realdonaldtrump',
#  '@cnn',
#  '@mariatcardona',
#  '@thisweekabc.',
#  '@billkristol',
#  '@mariatcardona',
#  '@thisweekabc.',
#  '@billkristol',
#  '@mariatcardona',
#  '@thisweekabc.',
#  '@billkristol',
#  '@billkristol,',
#  '@mattbai?',
#  '@mariatcardona.',
#  '@cnn',
#  '@cnn',
#  '@foxnews',
#  '@politico',
#  '@politico',
#  '@politico',
#  '@politico',
#  '@washingtonpost',
#  '@washingtonpost',
#  '@macys',
#  '@sopandeb',
#  '@',
#  '@sopandeb',
#  '@',
#  '@sopandeb',
#  '@',
#  '@sopandeb',
#  '@',
#  '@sopandeb',
#  '@',
#  '@maddow,',
#  '@katyturnbc',
#  '@maddow,',
#  '@katyturnbc',
#  '@debsopan',
#  '@gatewaypundit',
#  '@debsopan',
#  '@gatewaypundit',
#  '@debsopan',
#  '@gatewaypundit',
#  '@debsopan',
#  '@gatewaypundit',
#  '@meetthepress',
#  '@chucktodd',
#  '@meetthepress',
#  '@chucktodd',
#  '@meetthepress',
#  '@chucktodd',
#  '@washingtonpost,',
#  '@jeffbezos',
#  '@amazon.',
#  '@washingtonpost,',
#  '@jeffbezos',
#  '@amazon.',
#  '@washingtonpost',
#  '@jeffbezos',
#  '@amazon!',
#  '@amazon',
#  '@washingtonpost',
#  '@amazon',
#  '@washingtonpost',
#  '@johnkasich',
#  '@johnkasich',
#  '@cnn',
#  '@nytimes.',
#  '@cnn',
#  '@nytimes.',
#  '@cnn',
#  '@wsj',
#  '@ap',
#  '@nytimes',
#  '@cnn',
#  '@nytimes',
#  '@cnn',
#  '@realdonaldtrump',
#  '@time',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@secupp,',
#  '@cnn',
#  '@secupp,',
#  '@therickwilson',
#  '@cnn',
#  '@therickwilson',
#  '@cnn',
#  '@karlrove',
#  '@karlrove',
#  '@karlrove',
#  '@oreillyfactor.',
#  '@oreillyfactor.',
#  '@cnn',
#  '@tedcruz',
#  '@karlrove',
#  '@karlrove',
#  '@karlrove',
#  '@alwaleed_talal',
#  '@alwaleed_talal',
#  '@karlrove',
#  '@karlrove',
#  '@karlrove',
#  '@karlrove',
#  '@foxnews',
#  '@karlrove',
#  '@foxnews',
#  '@karlrove',
#  '@foxnews',
#  '@foxnews',
#  '@cnn',
#  '@peterose_14',
#  '@oreillyfactor,',
#  '@krauthammer.',
#  '@cnn',
#  '@cnn',
#  '@foxnews,',
#  '@megynkelly',
#  '@krauthammer,',
#  '@karlrove,',
#  '@georgezwill,',
#  '@megynkelly,',
#  '@foxnews',
#  '@krauthammer,',
#  '@karlrove,',
#  '@georgezwill,',
#  '@megynkelly,',
#  '@foxnews',
#  '@krauthammer,',
#  '@karlrove,',
#  '@georgezwill,',
#  '@megynkelly,',
#  '@foxnews',
#  '@krauthammer,',
#  '@karlrove,',
#  '@georgezwill,',
#  '@megynkelly,',
#  '@foxnews',
#  '@krauthammer,',
#  '@karlrove,',
#  '@georgezwill,',
#  '@megynkelly,',
#  '@foxnews',
#  '@drudge_report,',
#  '@time',
#  '@slate',
#  '@megynkelly',
#  '@drudge_report,',
#  '@time',
#  '@slate',
#  '@megynkelly',
#  '@melindadc',
#  '@jebbush',
#  '@jebbush',
#  '@jebbush',
#  '@jebbush',
#  '@foxnews:',
#  '@jebbush,',
#  '@jebbush,',
#  '@jebbush,',
#  '@jebbush,',
#  '@cnn',
#  '@secupp',
#  '@cnn',
#  '@secupp',
#  '@washingtonpost,',
#  '@tedcruz',
#  '@cnn',
#  '@foxnews',
#  '@karlrove',
#  '@foxnews',
#  '@karlrove',
#  '@foxnews',
#  '@karlrove',
#  '@jebbush',
#  '@jebbush',
#  '@jebbush',
#  '@jebbush',
#  '@jebbush',
#  '@cnn',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@chucktodd',
#  '@cnn',
#  '@chucktodd',
#  '@cnn',
#  '@nbc',
#  '@jebbush',
#  '@jebbush',
#  '@ananavarro',
#  '@secupp,',
#  '@cnn',
#  '@jebbush',
#  '@ananavarro',
#  '@secupp,',
#  '@cnn',
#  '@jebbush',
#  '@ananavarro',
#  '@secupp,',
#  '@cnn',
#  '@jebbush',
#  '@ananavarro',
#  '@secupp,',
#  '@cnn',
#  '@tgowdysc',
#  '@unionleader',
#  '@unionleader',
#  '@unionleader',
#  '@unionleader',
#  '@unionleader',
#  '@jebbush',
#  '@washingtonpost',
#  '@washingtonpost',
#  '@jebbush’s',
#  '@unionleader',
#  '@unionleader',
#  '@samuelljackson,',
#  '@samuelljackson,',
#  '@samuelljackson',
#  '@samuelljackson’s',
#  '@unionleader',
#  '@unionleader',
#  '@unionleader',
#  '@jebbush',
#  '@jebbush',
#  '@theview',
#  '@abc,',
#  '@barbarajwalters,',
#  '@theview',
#  '@abc,',
#  '@barbarajwalters,',
#  '@theview',
#  '@abc,',
#  '@barbarajwalters,',
#  '@theview.',
#  '@jebbush',
#  '@unionleader',
#  '@thisweekabc',
#  '@gstephanopoulos',
#  '@tavissmiley',
#  '@abc',
#  '@abc',
#  '@unionleader',
#  '@abc',
#  '@unionleader',
#  '@abc',
#  '@unionleader',
#  '@cbsnews',
#  '@cbsnews',
#  '@cbsnews',
#  '@tedcruz',
#  '@cnn',
#  '@andersoncooper',
#  '@',
#  '@andersoncooper',
#  '@glennbeck',
#  '@foxnews',
#  '@megynkelly',
#  '@tedcruz',
#  '@tedcruz',
#  '@howardstern',
#  '@howardstern',
#  '@glennbeck',
#  '@sarahpalinusa',
#  '@glennbeck',
#  '@sarahpalinusa',
#  '@glennbeck',
#  '@sarahpalinusa',
#  '@cnn',
#  '@cnn',
#  '@jebbush',
#  '@jebbush',
#  '@jebbush',
#  '@alisyncamerota',
#  '@alisyncamerota',
#  '@alisyncamerota',
#  '@greta',
#  '@nro',
#  '@jebbush',
#  '@jebbush',
#  '@nro',
#  '@nro',
#  '@glennbeck',
#  '@glennbeck',
#  '@',
#  '@glennbeck',
#  '@',
#  '@glennbeck',
#  '@glennbeck',
#  '@bobvanderplaats',
#  '@foxnews',
#  '@foxnews',
#  '@foxnews',
#  '@megynkelly.',
#  '@megynkelly.',
#  '@krauthammer,',
#  '@foxnews',
#  '@krauthammer,',
#  '@foxnews',
#  '@bensasse',
#  '@greta',
#  '@greta',
#  '@greta',
#  '@bensasse,',
#  '@bensasse,',
#  '@foxandfriends',
#  '@foxandfriends',
#  '@donlemon',
#  '@kayleighmcenany',
#  '@cherijacobus',
#  '@cnn',
#  '@donlemon',
#  '@kayleighmcenany',
#  '@cherijacobus',
#  '@cnn',
#  '@billoreilly',
#  '@karlrove.',
#  '@cherijacobus.',
#  '@cherijacobus.',
#  '@cherijacobus.',
#  '@jebbush',
#  '@nydailynews,',
#  '@nydailynews,',
#  '@nydailynews,',
#  '@nydailynews,',
#  '@politico',
#  '@nydailynews',
#  '@nydailynews',
#  '@nydailynews',
#  '@realbencarson.',
#  '@nydailynews,',
#  '@nydailynews,',
#  '@jebbush',
#  '@jebbush',
#  '@jebbush',
#  '@tedcruz',
#  '@jebbush',
#  '@marcorubio',
#  '@sentedcruz',
#  '@jebbush,',
#  '@nydailynews',
#  '@realbencarson-',
#  '@realbencarson-',
#  '@jebbush',
#  '@glennbeck-',
#  '@foxnews',
#  '@foxnews',
#  '@brithume',
#  '@megynkelly,',
#  '@megynkelly',
#  '@megynkelly',
#  '@foxnews.',
#  '@lindseygrahamsc,',
#  '@wsj',
#  '@wsj',
#  '@wsj',
#  '@wsj',
#  '@oreillyfactor',
#  '@brithume',
#  '@karlrove',
#  '@foxnews',
#  '@karlrove.',
#  '@mittromney',
#  '@foxandfriends',
#  '@foxandfriends',
#  '@foxnews',
#  '@foxnews',
#  '@foxnews',
#  '@chucktodd',
#  '@chucktodd',
#  '@chucktodd',
#  '@nbcnews',
#  '@wsj',
#  '@nbcnews',
#  '@wsj',
#  '@foxnews',
#  '@politico',
#  '@nydailynews',
#  '@politico',
#  '@nydailynews',
#  '@politico',
#  '@nydailynews',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@megynkelly',
#  '@megynkelly',
#  '@megynkelly',
#  '@megynkelly',
#  '@megynkelly',
#  '@foxnews',
#  '@megynkelly',
#  '@oreillyfactor',
#  '@megynkelly',
#  '@oreillyfactor',
#  '@wsj',
#  '@megynkelly',
#  '@megynkelly',
#  '@megynkelly',
#  '@megynkelly',
#  '@megynkelly',
#  '@megynkelly',
#  '@nytdavidbrooks',
#  '@nytdavidbrooks',
#  '@nytdavidbrooks',
#  '@nytdavidbrooks',
#  '@megynkelly',
#  '@megynkelly',
#  '@megynkelly,',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@abc',
#  '@foxnews',
#  '@chucktodd',
#  '@chucktodd',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@megynkelly',
#  '@politico',
#  '@politico',
#  '@politico',
#  '@nytimes',
#  '@oreillyfactor',
#  '@oreillyfactor',
#  '@oreillyfactor',
#  '@nytimes',
#  '@nytimes',
#  '@facethenation.',
#  '@facethenation.',
#  '@joenbc',
#  '@morning_joe',
#  '@teamsters',
#  '@morning_joe',
#  '@morning_joe',
#  '@marthamaccallum',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@foxandfriends',
#  '@nytimes',
#  '@nytimes',
#  '@cnn,',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@foxandfriends.',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes,',
#  '@cnn',
#  '@nytimes',
#  '@nytimes',
#  '@cnn',
#  '@cnn',
#  '@alisonforky',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nra',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@billkristol',
#  '@ed_klein',
#  '@dailymail-',
#  '@nytimes',
#  '@',
#  '@elizabethforma',
#  '@elizabethforma',
#  '@elizabethforma',
#  '@elizabethforma',
#  '@nytimes',
#  '@nytimes,',
#  '@nytimes,',
#  '@morning_joe',
#  '@morning_joe',
#  '@morning_joe',
#  '@cnn,',
#  '@cnn,',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@morning_joe',
#  '@morning_joe',
#  '@morning_joe',
#  '@nytimes',
#  '@abc',
#  '@abc',
#  '@washingtonpost',
#  '@uschamber',
#  '@nbcnews',
#  '@uschamber',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@meetthepress',
#  '@meetthepress',
#  '@markhalperin',
#  '@nbcpolitics',
#  '@markhalperin',
#  '@nbcpolitics',
#  '@cnn?',
#  '@cnn?',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@quinnipiacpoll.',
#  '@quinnipiacpoll.',
#  '@quinnipiacpoll.',
#  '@cnn,',
#  '@cnn,',
#  '@cnn,',
#  '@cnn,',
#  '@foxnews',
#  '@cnn',
#  '@foxnews',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@foxnews',
#  '@cnn',
#  '@foxnews',
#  '@foxnews',
#  '@megynkelly',
#  '@megynkelly',
#  '@nytimes',
#  '@cnn',
#  '@morning_joe',
#  '@cnn',
#  '@morning_joe',
#  '@cnn',
#  '@morning_joe',
#  '@cnn',
#  '@morning_joe',
#  '@nytimes',
#  '@cnn',
#  '@nytimes',
#  '@cnn',
#  '@nytimes',
#  '@cnn',
#  '@nytimes',
#  '@cnn',
#  '@nytimes',
#  '@cnn',
#  '@nytimes',
#  '@cnn',
#  '@cnn.',
#  '@cnn.',
#  '@cnn.',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes,',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@morning_joe',
#  '@morning_joe',
#  '@morning_joe',
#  '@morningmika',
#  '@morning_joe',
#  '@morningmika',
#  '@morning_joe',
#  '@morningmika',
#  '@morning_joe',
#  '@morningmika',
#  '@morning_joe',
#  '@morningmika',
#  '@morning_joe',
#  '@morningmika',
#  '@joenbc',
#  '@morningmika.',
#  '@joenbc',
#  '@morningmika.',
#  '@joenbc',
#  '@morningmika.',
#  '@washingtonpost',
#  '@washingtonpost',
#  '@washingtonpost',
#  '@pastormarkburns',
#  '@msnbc',
#  '@morningmika',
#  '@morning_joe.',
#  '@pastormarkburns',
#  '@msnbc',
#  '@morningmika',
#  '@morning_joe.',
#  '@morningmika',
#  '@morning_joe.',
#  '@morningmika',
#  '@morning_joe.',
#  '@morningmika',
#  '@morning_joe.',
#  '@morningmika',
#  '@morning_joe.',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@jeffflake,',
#  '@cnn',
#  '@cnn',
#  '@nbc',
#  '@cnn.',
#  '@cnn',
#  '@tonyschwartz,',
#  '@tonyschwartz,',
#  '@tonyschwartz,',
#  '@tonyschwartz',
#  '@tonyschwartz',
#  '@tonyschwartz',
#  '@tonyschwartz',
#  '@nytimes,',
#  '@nytimes,',
#  '@nytimesdowd,',
#  '@nytimesdowd,',
#  '@nytimesdowd,',
#  '@nytimesdowd,',
#  '@nytimesdowd,',
#  '@nytimes,',
#  '@nytimes,',
#  '@nytimes,',
#  '@nytimes,',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@hillaryclinton:',
#  '@hillaryclinton:',
#  '@cnn',
#  '@cnn',
#  '@donlemon,',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@foxnews',
#  '@cnn',
#  '@foxnews',
#  '@cnn',
#  '@foxnews',
#  '@cnn',
#  '@foxnews',
#  '@hillaryclinton',
#  '@hillaryclinton',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@cnn',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@nytimes',
#  '@ncgop',
#  "@hillaryclinton's",
#  '@abc',
#  ...]

# %%
sozluk={}
for etiket in etiketler:
  sozluk[etiket]=etiketler.count(etiket)

# %%
sozluk
# Out:
# {'@senatorcardin': 1,
#  '@neilyoung': 1,
#  '@foxnews': 278,
#  '@alwaleedbint': 1,
#  '@macys.': 1,
#  '@macys': 10,
#  '@ericbolling': 1,
#  '@krauthammer': 5,
#  '@clare_oc': 7,
#  '@forbes': 7,
#  '@forbes:': 1,
#  '@univision.': 3,
#  '@chucktodd': 17,
#  '@mets': 1,
#  '@nydailynews': 8,
#  '@karlrove': 35,
#  '@foxnews?': 2,
#  '@pennjillette': 5,
#  '@lawrence': 5,
#  '@pennjillette.': 2,
#  '@ariannahuff': 6,
#  '@huffingtonpost': 8,
#  '@cnn': 270,
#  '@cnnpolitics': 7,
#  '@mittromney?': 2,
#  '@wsj': 27,
#  '@wsj.': 1,
#  '@nbc': 11,
#  '@macys,': 2,
#  '@andersoncooper': 4,
#  '@danaperino.': 1,
#  '@ppfa': 1,
#  '@seanhannity': 17,
#  '@morning_joe': 33,
#  '@danhenninger': 1,
#  '@nytimes': 287,
#  '@drudge_report': 1,
#  '@time': 4,
#  '@megynkelly': 29,
#  '@megynkelly,': 9,
#  '@redstate': 4,
#  '@foxnews.': 39,
#  '@randpaul': 3,
#  '@abcpolitics': 1,
#  '@oreillyfactor': 8,
#  '@oreillyfactor,': 2,
#  '@thefive': 4,
#  '@cnn.': 40,
#  '@sentedcruz': 2,
#  '@ingrahamangle': 6,
#  '@foxnews,': 20,
#  '@bobbyjindal,': 2,
#  '@randpaul,': 1,
#  '@club4growth': 3,
#  '@richlowry': 3,
#  '@politico': 22,
#  '@marcorubio': 6,
#  '@glennbeck': 14,
#  '@ewerickson': 2,
#  '@politico,': 2,
#  '@60minutes': 7,
#  '@gop': 4,
#  '@cnbc': 3,
#  '@vanityfair': 8,
#  '@jebbush,': 6,
#  '@mittromney': 5,
#  '@jaketapper.': 4,
#  '@billkristol,': 3,
#  '@glennbeck,': 1,
#  '@politico.': 1,
#  '@cnbc.': 3,
#  '@fortunemagazine': 1,
#  '@realdonaldtrump': 5,
#  '@billkristol': 6,
#  '@jmartnyt': 2,
#  '@shepnewsteam': 2,
#  '@rondarousey': 1,
#  '@tmobile': 3,
#  '@ap.': 2,
#  '@georgewill,': 6,
#  '@georgewill': 1,
#  '@thejuanwilliams': 1,
#  '@billdeblasio,': 3,
#  '@ap': 4,
#  '@reuters': 1,
#  '@jeffhorwitz': 3,
#  '@greta': 8,
#  '@morning_joe.': 9,
#  '@mariatcardona': 3,
#  '@thisweekabc.': 3,
#  '@mattbai?': 1,
#  '@mariatcardona.': 1,
#  '@washingtonpost': 35,
#  '@sopandeb': 5,
#  '@': 12,
#  '@maddow,': 2,
#  '@katyturnbc': 2,
#  '@debsopan': 4,
#  '@gatewaypundit': 4,
#  '@meetthepress': 7,
#  '@washingtonpost,': 16,
#  '@jeffbezos': 3,
#  '@amazon.': 2,
#  '@amazon!': 1,
#  '@amazon': 2,
#  '@johnkasich': 4,
#  '@nytimes.': 9,
#  '@secupp,': 6,
#  '@therickwilson': 2,
#  '@oreillyfactor.': 2,
#  '@tedcruz': 6,
#  '@alwaleed_talal': 2,
#  '@peterose_14': 1,
#  '@krauthammer.': 1,
#  '@krauthammer,': 7,
#  '@karlrove,': 5,
#  '@georgezwill,': 5,
#  '@drudge_report,': 2,
#  '@slate': 2,
#  '@melindadc': 1,
#  '@jebbush': 29,
#  '@foxnews:': 2,
#  '@secupp': 2,
#  '@ananavarro': 4,
#  '@tgowdysc': 1,
#  '@unionleader': 14,
#  '@jebbush’s': 1,
#  '@samuelljackson,': 2,
#  '@samuelljackson': 1,
#  '@samuelljackson’s': 1,
#  '@theview': 3,
#  '@abc,': 17,
#  '@barbarajwalters,': 3,
#  '@theview.': 1,
#  '@thisweekabc': 1,
#  '@gstephanopoulos': 5,
#  '@tavissmiley': 1,
#  '@abc': 22,
#  '@cbsnews': 6,
#  '@howardstern': 2,
#  '@sarahpalinusa': 3,
#  '@alisyncamerota': 3,
#  '@nro': 3,
#  '@bobvanderplaats': 1,
#  '@megynkelly.': 2,
#  '@bensasse': 1,
#  '@bensasse,': 2,
#  '@foxandfriends': 116,
#  '@donlemon': 2,
#  '@kayleighmcenany': 2,
#  '@cherijacobus': 2,
#  '@billoreilly': 1,
#  '@karlrove.': 2,
#  '@cherijacobus.': 3,
#  '@nydailynews,': 6,
#  '@realbencarson.': 1,
#  '@realbencarson-': 2,
#  '@glennbeck-': 1,
#  '@brithume': 2,
#  '@lindseygrahamsc,': 1,
#  '@nbcnews': 36,
#  '@nytdavidbrooks': 4,
#  '@facethenation.': 2,
#  '@joenbc': 4,
#  '@teamsters': 1,
#  '@marthamaccallum': 5,
#  '@cnn,': 42,
#  '@foxandfriends.': 5,
#  '@nytimes,': 68,
#  '@alisonforky': 1,
#  '@nra': 1,
#  '@ed_klein': 1,
#  '@dailymail-': 1,
#  '@elizabethforma': 4,
#  '@uschamber': 2,
#  '@markhalperin': 2,
#  '@nbcpolitics': 2,
#  '@cnn?': 8,
#  '@quinnipiacpoll.': 3,
#  '@morningmika': 12,
#  '@morningmika.': 3,
#  '@pastormarkburns': 2,
#  '@msnbc': 23,
#  '@jeffflake,': 1,
#  '@tonyschwartz,': 3,
#  '@tonyschwartz': 4,
#  '@nytimesdowd,': 5,
#  '@hillaryclinton:': 2,
#  '@donlemon,': 1,
#  '@hillaryclinton': 2,
#  '@ncgop': 1,
#  "@hillaryclinton's": 1,
#  '@koster4missouri!': 1,
#  '@ericgreitens!': 1,
#  '@nbcsnl': 1,
#  '@jeffzeleny': 3,
#  '@nbcnightlynews': 2,
#  '@chucktodd.': 2,
#  '@nordstrom.': 2,
#  '@nbcnews,': 19,
#  '@cbs,': 11,
#  '@cnn)': 11,
#  '@senschumer': 3,
#  '@snoopdogg,': 1,
#  '@ossoff,': 1,
#  '@washingtonpost?': 8,
#  '@comcast': 5,
#  '@senatemajldr': 10,
#  '@lisamurkowski': 1,
#  '@breitbartnews...maybe': 1,
#  '@nytimes(apologized)': 11,
#  '@wapo': 13,
#  '@vp': 7,
#  '@nbcnews.': 6,
#  '@secondlady': 1,
#  '@cnn!': 7,
#  '@cbsnews,': 6,
#  '@tuckercarlson': 6,
#  '@edwgillespie': 1,
#  '@cfpb': 1,
#  '@foxandfrlends': 2,
#  '@tuckercarlson.': 4,
#  '@wattersworld': 1,
#  '@greggutfeld': 6,
#  '@petehegseth': 4,
#  '@g7': 2,
#  '@rothfusforpa.': 1,
#  '@rt_erdogan': 1,
#  '@judicialwatch': 9,
#  '@foxbusiness': 2,
#  '@parisdennard': 2,
#  '@carlbernstein,': 6,
#  '@savannahguthrie': 3,
#  '@todayshow': 3,
#  '@mariabartiromo': 13,
#  '@foxbusiness.': 3,
#  '@repmcsally': 2,
#  '@rondesantisfl': 7,
#  '@marthamcsally': 2,
#  '@mattformontana': 1,
#  '@gregformontana!': 1,
#  '@claudiatenney': 1,
#  '@andrewgillum': 1,
#  '@hawleymo!': 3,
#  '@ustreasury': 3,
#  '@stevenmnuchin1.': 2,
#  '@emmanuelmacron': 2,
#  '@trish_regan': 4,
#  '@geraldorivera': 1,
#  '@richardgrenell,': 1,
#  '@spoxdhs': 2,
#  '@tsa': 2,
#  '@jessebwatters': 3,
#  '@johnrobertsfox': 2,
#  '@gillianhturner': 2,
#  '@thehill': 1,
#  '@anncoulter,': 2,
#  '@grahamledger': 4,
#  '@jasoninthehouse': 2,
#  '@oann': 30,
#  '@judgejeanine': 5,
#  '@kennedynation': 1,
#  '@byronyork': 2,
#  '@billhemmer': 3,
#  '@senrickscott': 2,
#  '@senjohnbarrasso': 2,
#  '@senbillcassidy': 2,
#  '@lindseygrahamsc': 6,
#  '@repdougcollins': 4,
#  '@60minutes,': 6,
#  '@justinamash,': 4,
#  '@devinnunes': 6,
#  '@shannonbream': 4,
#  '@abeshinzo.': 1,
#  '@marcthiessen.': 1,
#  '@att': 3,
#  '@bettemidler': 3,
#  '@maddow': 2,
#  '@washingtonpost.': 11,
#  '@donnydeutsch': 4,
#  '@erinburnett': 6,
#  '@repadamschiff': 1,
#  '@marshablackburn': 7,
#  '@markwarner': 2,
#  '@abc.': 1,
#  '@abcnews': 6,
#  '@bretbaier': 2,
#  '@meganrapino': 1,
#  '@joebiden': 1,
#  '@donnabrazile': 5,
#  '@theresa_may': 1,
#  '@alfredeneuman99..': 1,
#  '@stevehiltonx': 1,
#  '@nextrevfnc': 1,
#  '@oann!': 3,
#  '@nytimes!': 3,
#  '@donnabrazile,': 1,
#  '@sandrasmithfox.': 1,
#  '@msnbc....': 1,
#  '@jonathancarl': 2,
#  '@abcworldnews.': 3,
#  '@jonkarl': 1,
#  '@loudobbs': 3,
#  '@jimcramer,': 1,
#  '@philiprucker': 5,
#  '@ashleyrparker,': 5,
#  '@johnlegend,': 3,
#  '@clewandowski_': 1,
#  '@lagop': 4,
#  '@gma,': 2,
#  '@eddierispone.': 2,
#  '@greggutfeldshow': 1,
#  '@gma.': 3,
#  '@repswalwell.': 6,
#  '@lindseygraham,': 2,
#  '@kamalaharris': 8,
#  '@varneyco': 2,
#  '@stevedoocy': 2,
#  '@gavinnewsom,': 1,
#  '@marklevinshow,': 1,
#  '@senjohnkennedy': 3,
#  '@eddierispone!': 2,
#  '@abc!': 3,
#  '@washtimes': 2,
#  '@washingtonpost!': 4,
#  '@cline4virginia': 2,
#  '@repandybiggsaz': 2,
#  '@repswalwell': 6,
#  '@brettkavanaugh,': 2,
#  '@kilmeade': 1,
#  '@gstephanopoulos,': 3,
#  '@greggjarrett': 4,
#  '@paulkrugman': 2,
#  '@corybooker': 6,
#  '@whitehouse': 1,
#  '@sencapito': 2,
#  '@leesmithdc': 2,
#  '@dougjones': 8,
#  '@teamcavuto,': 1,
#  '@tulsigabbard': 3,
#  '@congressmanjvd!': 1,
#  '@cdcgov.....': 5,
#  '@johnjharwood,': 4,
#  '@rudygiuliani': 4,
#  '@ericgarcetti,': 1,
#  '@ronaldklain,': 2,
#  '@hhsgov': 1,
#  '@secazar': 5,
#  '@amyklobuchar': 8,
#  '@petebuttigieg': 2,
#  '@cnn’s': 3,
#  '@dhs_wolf': 2,
#  '@repthomasmassie,': 1,
#  '@repthomasmassie\n': 1,
#  '@nytimes)': 4,
#  '@gavinnewsom': 4,
#  '@peternavarrousa': 2,
#  '@vp)': 1,
#  '@alexazar': 2,
#  '@markmeadows': 2,
#  '@mikegarcia2020.': 1,
#  '@mikegarcia2020,': 2,
#  '@ajitpaifcc': 4,
#  '@fcc': 4,
#  '@norahodonnell,': 4,
#  '@secazar,': 1,
#  '@norahodonnell': 1,
#  '@sensusancollins': 2,
#  '@marklevinshow': 2,
#  '@russvought45': 4,
#  '@dougjones,': 3,
#  '@ttuberville': 6,
#  '@pulitzerprizes': 3,
#  '@yoyoel': 4,
#  '@murielbowser,': 1,
#  '@johnwhuber': 3,
#  '@nycmayor': 1,
#  '@nygovcuomo': 1,
#  '@mayorbowser,': 2,
#  '@charleshurt': 2,
#  '@seanparnellusa,': 5,
#  '@govmikehuckabee.': 3,
#  '@tomcottonar.': 1,
#  '@lacyjohnsonmn': 1,
#  '@jim_jordan': 2,
#  '@jayinslee': 6,
#  '@dhsgov': 4,
#  '@mayorbowser': 1,
#  '@vp.': 2,
#  '@nytimesbooks,': 2,
#  '@breitbartnews': 11,
#  '@newsmax': 8,
#  '@bubbawallace': 1,
#  '@cdcgov': 2,
#  '@ttuberville,': 2,
#  '@stevehiltonx,': 3,
#  '@billmaher': 5,
#  '@nra.': 1,
#  '@oann.': 4,
#  '@repdebdingell.': 2,
#  '@uspostoffice911': 1,
#  '@michelleobama': 1,
#  '@latimes': 4,
#  '@dni_ratcliffe': 4,
#  '@nba.': 2,
#  '@thejusticedept': 5,
#  '@fbi': 2,
#  '@hawleymo': 2,
#  '@mittromney,': 1,
#  '@drudge': 2,
#  '@thenatpulse': 2,
#  '@govsisolak,': 3,
#  '@mike_pence.': 2,
#  '@truethevote': 3,
#  '@senategop': 1,
#  '@fda': 1,
#  '@breitbartnews.': 6,
#  '@nba,': 2,
#  '@gopleader': 2,
#  '@nypost.': 2,
#  '@cspan': 7,
#  '@nypost': 4,
#  '@thebabylonbee': 2,
#  '@sensasse': 6,
#  '@nypost,': 2,
#  '@60minutes.': 1,
#  '@google.': 3,
#  '@donnashalala,': 3,
#  '@andersoncooper,': 4,
#  '@nancymace!': 1,
#  '@mschlapp': 1,
#  '@adamlaxalt': 1,
#  '@us_fda': 6,
#  '@pfizer': 1,
#  '@quinnipiacpoll,': 8,
#  '@abc/@washingtonpost': 3,
#  '@foxnews!': 3,
#  '@briankempga?': 1,
#  '@briankempga': 29,
#  '@alfredenewman1': 3,
#  '@newsmax,': 4,
#  '@gasecofstate': 1,
#  '@oann,': 4,
#  '@dougducey?': 1,
#  '@briankempga,': 14,
#  '@briankempga.': 3,
#  '@dougducey': 6,
#  '@geoffduncanga,': 23,
#  '@sendavidperdue': 7,
#  '@kloeffler.': 6,
#  '@geoffduncanga': 4,
#  '@geoffduncanga.': 3,
#  '@stevefda.': 3,
#  '@staceyabrams': 6,
#  '@senronjohnson': 1,
#  '@donnabraziie,': 5,
#  '@kloeffler': 8,
#  '@kristinoem,': 1,
#  '@senjohnthune,': 1,
#  '@cdcgov’s': 1,
#  '@sentomcotton': 1,
#  '@johncornyn': 1,
#  '@senjohnthune': 1,
#  '@deptofdefense': 1,
#  '@secbernhardt': 1,
#  '@secretservice': 1,
#  '@mike_pence': 1}

# %%
tagdf=pd.DataFrame()

# %%
tagdf["tag"]=sozluk.keys()
tagdf["adet"]=sozluk.values()

# %%
tagdf.head(10)
# Out:
#               tag  adet
# 0  @senatorcardin     1
# 1      @neilyoung     1
# 2        @foxnews   278
# 3   @alwaleedbint     1
# 4         @macys.     1
# 5          @macys    10
# 6    @ericbolling     1
# 7    @krauthammer     5
# 8       @clare_oc     7
# 9         @forbes     7

# %%
tagdf.sort_values( by="adet" , ascending=False)
# Out:
#                 tag  adet
# 35         @nytimes   287
# 2          @foxnews   278
# 22             @cnn   270
# 147  @foxandfriends   116
# 168       @nytimes,    68
# ..              ...   ...
# 261  @kennedynation     1
# 273     @abeshinzo.     1
# 274  @marcthiessen.     1
# 281  @repadamschiff     1
# 466     @mike_pence     1
#
# [467 rows x 2 columns]
